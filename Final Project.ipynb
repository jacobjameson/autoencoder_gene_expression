# %% [markdown]
# # CMSC 35300 Final Project
# ## Jacob Jameson & Hugo Salas
#
# ### Creating an Autoencoder for Gene Expression Data

# %% [markdown]
# **In this notebook, we build an autoencoder neural network that takes gene expression data from protein-coding genes only, encodes them through multiple layers of decreasing dimensions, and then decodes them back the original dimensionality as what was inputted.**

# %%
import requests
import json
import re
import gzip
import shutil
import pandas as pd
import os
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
from sklearn import preprocessing
from sklearn.manifold import TSNE

import seaborn as sns
# %matplotlib inline 

from keras.layers import Input, Dense
from keras.models import Model
from keras import optimizers
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.preprocessing import StandardScaler, Normalizer

# %% [markdown]
# **In the code below, I import the RNA sequence samples and create a dataframe where each row is one sample and the columns are the genes in that sample. I used 137 female samples to construct my dataset. I first downloaded the data from the portal, so the code below loops through the data already downloaded to open and merge it together.**

# %%
directory = "/Users/jacob/Downloads/ML for Medicine/Assignment 2/gdc_download_20211025_201031.006887"
folder_names = []
for filename in os.listdir(directory):
    if not filename.endswith(".DS_Store") and not filename.endswith(".txt"):
        folder_names.append(os.path.join(directory, filename))

file_names = []
for folder in folder_names:
    for filename in os.listdir(folder):
        if filename.endswith(".gz"):
            file_names.append(os.path.join(folder, filename))

# %%
for n, file in enumerate(file_names):
    with gzip.open(file, 'rb') as f_in:
        with open(file + '.txt', 'wb') as f_out:
            shutil.copyfileobj(f_in, f_out)
            
    data = pd.read_csv(file + '.txt', sep='\t', 
                       header=None).rename(columns={0: "Gene", 1: "Sample"})
    data.drop(data.tail(5).index,inplace=True)
    data = data.rename(columns={"Sample": "Sample " + str(n + 1)})
    if n > 0:
        grouped_df = data.merge(grouped_df, how='left', on='Gene')
    else:
        grouped_df = data
        
grouped_df = grouped_df.set_index('Gene')
final_data = grouped_df.T

# %%
final_data
# Out:
# Gene        ENSG00000000003.13  ENSG00000000005.5  ENSG00000000419.11  \
# Sample 137                1603                  1                2036
# Sample 136                3901                  0                4442
# Sample 135                 393                  0                2140
# Sample 134                 957                  1                3664
# Sample 133                 725                  2                1172
# ...                        ...                ...                 ...
# Sample 5                   790                139                2331
# Sample 4                  1827                  4                3786
# Sample 3                  9582                  0                4265
# Sample 2                   631                  2                2857
# Sample 1                  2715                  2                3168
#
# Gene        ENSG00000000457.12  ENSG00000000460.15  ENSG00000000938.11  \
# Sample 137                1609                 443                 938
# Sample 136                1489                1133                 212
# Sample 135                1232                 321                 153
# Sample 134                1231                 735                 511
# Sample 133                 654                 245                 399
# ...                        ...                 ...                 ...
# Sample 5                   654                 391                 350
# Sample 4                  1192                 760                 973
# Sample 3                   923                 485                 722
# Sample 2                   716                 625                 787
# Sample 1                  1352                1346                 451
#
# Gene        ENSG00000000971.14  ENSG00000001036.12  ENSG00000001084.9  \
# Sample 137               21034                6496               4427
# Sample 136                2426                4387               2457
# Sample 135                 939                2923               1681
# Sample 134                8050                7202               6800
# Sample 133                2492                2023               1110
# ...                        ...                 ...                ...
# Sample 5                  4699                2361               1760
# Sample 4                  6990                5020               4228
# Sample 3                  2209                4603               2698
# Sample 2                  6451                4200               2279
# Sample 1                  3691                7634               5798
#
# Gene        ENSG00000001167.13  ...  ENSGR0000263980.4  ENSGR0000264510.4  \
# Sample 137                2711  ...                  0                  0
# Sample 136                2646  ...                  0                  0
# Sample 135                1630  ...                  0                  0
# Sample 134                2342  ...                  0                  0
# Sample 133                 656  ...                  0                  0
# ...                        ...  ...                ...                ...
# Sample 5                  1375  ...                  0                  0
# Sample 4                  2428  ...                  0                  0
# Sample 3                  1860  ...                  0                  0
# Sample 2                  2711  ...                  0                  0
# Sample 1                  4793  ...                  0                  0
#
# Gene        ENSGR0000264819.4  ENSGR0000265658.4  ENSGR0000270726.4  \
# Sample 137                  0                  0                  0
# Sample 136                  0                  0                  0
# Sample 135                  0                  0                  0
# Sample 134                  0                  0                  0
# Sample 133                  0                  0                  0
# ...                       ...                ...                ...
# Sample 5                    0                  0                  0
# Sample 4                    0                  0                  0
# Sample 3                    0                  0                  0
# Sample 2                    0                  0                  0
# Sample 1                    0                  0                  0
#
# Gene        ENSGR0000275287.3  ENSGR0000276543.3  ENSGR0000277120.3  \
# Sample 137                  0                  0                  0
# Sample 136                  0                  0                  0
# Sample 135                  0                  0                  0
# Sample 134                  0                  0                  0
# Sample 133                  0                  0                  0
# ...                       ...                ...                ...
# Sample 5                    0                  0                  0
# Sample 4                    0                  0                  0
# Sample 3                    0                  0                  0
# Sample 2                    0                  0                  0
# Sample 1                    0                  0                  0
#
# Gene        ENSGR0000280767.1  ENSGR0000281849.1
# Sample 137                  0                  0
# Sample 136                  0                  0
# Sample 135                  0                  0
# Sample 134                  0                  0
# Sample 133                  0                  0
# ...                       ...                ...
# Sample 5                    0                  0
# Sample 4                    0                  0
# Sample 3                    0                  0
# Sample 2                    0                  0
# Sample 1                    0                  0
#
# [137 rows x 60483 columns]

# %% [markdown]
# ## Pre-Processing
#
# **Only keep genes that are protein encoding genes.**

# %%
nt_coding = pd.read_csv('MLiB-Lab3-PartA/nt.coding.csv')
nt_coding.drop('Type', axis=1, inplace=True)

final_data_coding = final_data[list(nt_coding.columns)]

final_data_coding
# Out:
# Gene        ENSG00000000003.13  ENSG00000000005.5  ENSG00000000419.11  \
# Sample 137                1603                  1                2036
# Sample 136                3901                  0                4442
# Sample 135                 393                  0                2140
# Sample 134                 957                  1                3664
# Sample 133                 725                  2                1172
# ...                        ...                ...                 ...
# Sample 5                   790                139                2331
# Sample 4                  1827                  4                3786
# Sample 3                  9582                  0                4265
# Sample 2                   631                  2                2857
# Sample 1                  2715                  2                3168
#
# Gene        ENSG00000000457.12  ENSG00000000460.15  ENSG00000000938.11  \
# Sample 137                1609                 443                 938
# Sample 136                1489                1133                 212
# Sample 135                1232                 321                 153
# Sample 134                1231                 735                 511
# Sample 133                 654                 245                 399
# ...                        ...                 ...                 ...
# Sample 5                   654                 391                 350
# Sample 4                  1192                 760                 973
# Sample 3                   923                 485                 722
# Sample 2                   716                 625                 787
# Sample 1                  1352                1346                 451
#
# Gene        ENSG00000000971.14  ENSG00000001036.12  ENSG00000001084.9  \
# Sample 137               21034                6496               4427
# Sample 136                2426                4387               2457
# Sample 135                 939                2923               1681
# Sample 134                8050                7202               6800
# Sample 133                2492                2023               1110
# ...                        ...                 ...                ...
# Sample 5                  4699                2361               1760
# Sample 4                  6990                5020               4228
# Sample 3                  2209                4603               2698
# Sample 2                  6451                4200               2279
# Sample 1                  3691                7634               5798
#
# Gene        ENSG00000001167.13  ...  ENSG00000269699.4  ENSG00000269711.1  \
# Sample 137                2711  ...                 11                  0
# Sample 136                2646  ...                  0                  0
# Sample 135                1630  ...                  0                  0
# Sample 134                2342  ...                  0                  0
# Sample 133                 656  ...                  9                  0
# ...                        ...  ...                ...                ...
# Sample 5                  1375  ...                  1                  0
# Sample 4                  2428  ...                 11                  0
# Sample 3                  1860  ...                  2                  0
# Sample 2                  2711  ...                  2                  0
# Sample 1                  4793  ...                  1                  0
#
# Gene        ENSG00000269741.4  ENSG00000269749.1  ENSG00000269755.1  \
# Sample 137                  0                  1                  8
# Sample 136                  0                  0                  1
# Sample 135                  0                  0                  2
# Sample 134                 10                  0                  1
# Sample 133                  0                  0                  3
# ...                       ...                ...                ...
# Sample 5                    0                  0                  1
# Sample 4                    5                  0                  7
# Sample 3                    0                  0                  2
# Sample 2                    1                  1                  0
# Sample 1                    1                  1                  2
#
# Gene        ENSG00000269846.1  ENSG00000269855.2  ENSG00000269858.4  \
# Sample 137                  7                  5               1128
# Sample 136                  0                  1               1377
# Sample 135                  0                 17                738
# Sample 134                 10                  2                691
# Sample 133                  5                  2                566
# ...                       ...                ...                ...
# Sample 5                    1                  0                857
# Sample 4                    7                 31                536
# Sample 3                    1                  0               1371
# Sample 2                   12                  7                567
# Sample 1                    7                  2                774
#
# Gene        ENSG00000269881.1  ENSG00000269883.1
# Sample 137                 36                  1
# Sample 136                  6                  0
# Sample 135                 34                  1
# Sample 134                  6                  0
# Sample 133                 19                  1
# ...                       ...                ...
# Sample 5                   16                  0
# Sample 4                    6                  7
# Sample 3                    5                  0
# Sample 2                   16                  1
# Sample 1                   12                  1
#
# [137 rows x 19561 columns]

# %% [markdown]
# **Normalize the data**

# %% [markdown]
# ## Autoencoder

# %%
X_train, X_test = train_test_split(final_data_coding, 
                                   test_size=0.3, 
                                   random_state=1)

scaler = Normalizer()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
input_layer = Input(shape=(X_train.shape[1],))
encoded = Dense(256, activation='relu')(input_layer)
encoded = Dense(128, activation='relu')(encoded)
encoded = Dense(50, activation='relu')(encoded)

decoded = Dense(128, activation='relu')(encoded)
decoded = Dense(256, activation='relu')(decoded)
decoded = Dense(X_train.shape[1], activation='sigmoid')(decoded)

# %%
autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(X_train, X_train,
                epochs=20,
                batch_size=20)
# Out:
# Epoch 1/20
# 5/5 [==============================] - 1s 50ms/step - loss: 0.6923
# Epoch 2/20
# 5/5 [==============================] - 0s 50ms/step - loss: 0.6884
# Epoch 3/20
# 5/5 [==============================] - 0s 53ms/step - loss: 0.6620
# Epoch 4/20
# 5/5 [==============================] - 0s 75ms/step - loss: 0.4848
# Epoch 5/20
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1101
# Epoch 6/20
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0129
# Epoch 7/20
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0207
# Epoch 8/20
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0268
# Epoch 9/20
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0277
# Epoch 10/20
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0254
# Epoch 11/20
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0219
# Epoch 12/20
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0186
# Epoch 13/20
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0158
# Epoch 14/20
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0136
# Epoch 15/20
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0121
# Epoch 16/20
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0110
# Epoch 17/20
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0103
# Epoch 18/20
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0099
# Epoch 19/20
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0096
# Epoch 20/20
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0094

# %%
autoencoder.evaluate(X_test, X_test, verbose=2)
# Out:
# 2/2 - 0s - loss: 0.0085 - 151ms/epoch - 76ms/step
# 0.008524371311068535

# %% [markdown]
# **Here we explore different bottleneck layers to see how compression effects our loss**

# %%
losses = dict()

for size in [10, 20, 30, 40, 60, 80]:
    input_layer = Input(shape=(X_train.shape[1],))
    encoded = Dense(256, activation='relu')(input_layer)
    encoded = Dense(128, activation='relu')(encoded)
    encoded = Dense(size, activation='relu')(encoded)

    decoded = Dense(128, activation='relu')(encoded)
    decoded = Dense(256, activation='relu')(decoded)
    decoded = Dense(X_train.shape[1], activation='sigmoid')(decoded)
    
    autoencoder = Model(input_layer, decoded)
    autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
    autoencoder.fit(X_train, X_train, epochs=20, batch_size=20)
    
    losses[size] = autoencoder.evaluate(X_test, X_test, verbose=2)
# Out:
# Epoch 1/20
# 5/5 [==============================] - 1s 46ms/step - loss: 0.6923
# Epoch 2/20
# 5/5 [==============================] - 0s 43ms/step - loss: 0.6894
# Epoch 3/20
# 5/5 [==============================] - 0s 45ms/step - loss: 0.6802
# Epoch 4/20
# 5/5 [==============================] - 0s 41ms/step - loss: 0.6207
# Epoch 5/20
# 5/5 [==============================] - 0s 46ms/step - loss: 0.3645
# Epoch 6/20
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0571
# Epoch 7/20
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0128
# Epoch 8/20
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0190
# Epoch 9/20
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0231
# Epoch 10/20
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0238
# Epoch 11/20
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0223
# Epoch 12/20
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0201
# Epoch 13/20
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0177
# Epoch 14/20
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0156
# Epoch 15/20
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0137
# Epoch 16/20
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0124
# Epoch 17/20
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0114
# Epoch 18/20
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0107
# Epoch 19/20
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0101
# Epoch 20/20
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0097
# 2/2 - 0s - loss: 0.0086 - 112ms/epoch - 56ms/step
# Epoch 1/20
# 5/5 [==============================] - 1s 60ms/step - loss: 0.6922
# Epoch 2/20
# 5/5 [==============================] - 0s 87ms/step - loss: 0.6884
# Epoch 3/20
# 5/5 [==============================] - 0s 76ms/step - loss: 0.6653
# Epoch 4/20
# 5/5 [==============================] - 0s 80ms/step - loss: 0.5265
# Epoch 5/20
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1733
# Epoch 6/20
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0163
# Epoch 7/20
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0164
# Epoch 8/20
# 5/5 [==============================] - 0s 77ms/step - loss: 0.0225
# Epoch 9/20
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0247
# Epoch 10/20
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0238
# Epoch 11/20
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0215
# Epoch 12/20
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0189
# Epoch 13/20
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0164
# Epoch 14/20
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0144
# Epoch 15/20
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0128
# Epoch 16/20
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0117
# Epoch 17/20
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0108
# Epoch 18/20
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0102
# Epoch 19/20
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0098
# Epoch 20/20
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0095
# 2/2 - 0s - loss: 0.0086 - 128ms/epoch - 64ms/step
# Epoch 1/20
# 5/5 [==============================] - 1s 79ms/step - loss: 0.6923
# Epoch 2/20
# 5/5 [==============================] - 0s 63ms/step - loss: 0.6890
# Epoch 3/20
# 5/5 [==============================] - 0s 51ms/step - loss: 0.6729
# Epoch 4/20
# 5/5 [==============================] - 0s 44ms/step - loss: 0.5620
# Epoch 5/20
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2189
# Epoch 6/20
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0168
# Epoch 7/20
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0166
# Epoch 8/20
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0233
# Epoch 9/20
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0258
# Epoch 10/20
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0249
# Epoch 11/20
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0224
# Epoch 12/20
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0195
# Epoch 13/20
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0166
# Epoch 14/20
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0144
# Epoch 15/20
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0126
# Epoch 16/20
# 5/5 [==============================] - 0s 77ms/step - loss: 0.0114
# Epoch 17/20
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0105
# Epoch 18/20
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0099
# Epoch 19/20
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0096
# Epoch 20/20
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0094
# 2/2 - 0s - loss: 0.0086 - 114ms/epoch - 57ms/step
# Epoch 1/20
# 5/5 [==============================] - 1s 38ms/step - loss: 0.6923
# Epoch 2/20
# 5/5 [==============================] - 0s 41ms/step - loss: 0.6891
# Epoch 3/20
# 5/5 [==============================] - 0s 42ms/step - loss: 0.6744
# Epoch 4/20
# 5/5 [==============================] - 0s 37ms/step - loss: 0.5749
# Epoch 5/20
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2405
# Epoch 6/20
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0194
# Epoch 7/20
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0166
# Epoch 8/20
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0236
# Epoch 9/20
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0266
# Epoch 10/20
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0255
# Epoch 11/20
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0224
# Epoch 12/20
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0190
# Epoch 13/20
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0156
# Epoch 14/20
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0132
# Epoch 15/20
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0114
# Epoch 16/20
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0103
# Epoch 17/20
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0096
# Epoch 18/20
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0094
# Epoch 19/20
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0093
# Epoch 20/20
# 5/5 [==============================] - 1s 144ms/step - loss: 0.0092
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7fe02515faf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 - 0s - loss: 0.0084 - 194ms/epoch - 97ms/step
# Epoch 1/20
# 5/5 [==============================] - 2s 62ms/step - loss: 0.6922
# Epoch 2/20
# 5/5 [==============================] - 0s 59ms/step - loss: 0.6883
# Epoch 3/20
# 5/5 [==============================] - 0s 62ms/step - loss: 0.6606
# Epoch 4/20
# 5/5 [==============================] - 0s 61ms/step - loss: 0.4774
# Epoch 5/20
# 5/5 [==============================] - 0s 56ms/step - loss: 0.1018
# Epoch 6/20
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0137
# Epoch 7/20
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0211
# Epoch 8/20
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0267
# Epoch 9/20
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0275
# Epoch 10/20
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0252
# Epoch 11/20
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0217
# Epoch 12/20
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0183
# Epoch 13/20
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0155
# Epoch 14/20
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0133
# Epoch 15/20
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0119
# Epoch 16/20
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0108
# Epoch 17/20
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0101
# Epoch 18/20
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0097
# Epoch 19/20
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0095
# Epoch 20/20
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0093
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fe025b41940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 - 0s - loss: 0.0085 - 140ms/epoch - 70ms/step
# Epoch 1/20
# 5/5 [==============================] - 1s 70ms/step - loss: 0.6922
# Epoch 2/20
# 5/5 [==============================] - 0s 61ms/step - loss: 0.6880
# Epoch 3/20
# 5/5 [==============================] - 0s 71ms/step - loss: 0.6579
# Epoch 4/20
# 5/5 [==============================] - 0s 71ms/step - loss: 0.4678
# Epoch 5/20
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0924
# Epoch 6/20
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0132
# Epoch 7/20
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0222
# Epoch 8/20
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0278
# Epoch 9/20
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0278
# Epoch 10/20
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0244
# Epoch 11/20
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0204
# Epoch 12/20
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0165
# Epoch 13/20
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0134
# Epoch 14/20
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0112
# Epoch 15/20
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0102
# Epoch 16/20
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0096
# Epoch 17/20
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0093
# Epoch 18/20
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0093
# Epoch 19/20
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0092
# Epoch 20/20
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0091
# 2/2 - 0s - loss: 0.0085 - 126ms/epoch - 63ms/step

# %%
losses
# Out:
# {10: 0.008590234443545341,
#  20: 0.008578382432460785,
#  30: 0.008572423830628395,
#  40: 0.008356384932994843,
#  60: 0.008510102517902851,
#  80: 0.008471248671412468}
